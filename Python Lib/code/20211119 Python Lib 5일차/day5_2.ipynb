# %%
# 쥬피터노트북 셀 스타일 조절 
from IPython.core.display import display, HTML
display(HTML("<style>.container { font-weight: bold !important; }</style>"))
display(HTML("<style>.container { width: 100% !important; }</style>"))

import warnings
warnings.filterwarnings(action='ignore')
# Out:
# <style>.container { font-weight: bold !important; }</style>
# <style>.container { width: 100% !important; }</style>

# %% [markdown]
# # # Selenium을 이용한 동적 컨텐츠 수집
# ```
# 원격으로 웹페이지 소스를 활용하기 위한 라이브러리
# 동적컨텐츠 수집에 주로 사용
# 작업환경 : 크롬 + 셀레니움용 웹드라이버 설치
# 주의사항 : 크롬 버전과 웹드라이버 버전이 일치
#
# 설치 과정
#
# 1) 크롬 웹브라우저 버전 확인
#  1시방향 옵션 버튼 클릭 후 [도움말]-[Chrome 정보] 확인
#  버전은?
#   예)96.0
# 2) 크롬 웹브라우저에 맞는 드라이버 파일 다운로드
#  https://chromedriver.chromium.org/downloads
#
#  윈도우용인 경우 :   chromedriver_win32.zip
#
#  쥬피터노트북 파일이 있는 폴더에 압축해제한다.
#  chromedriver.exe 파일이 있는지 확인
# 3) 셀레니움 설치
#  pip list 로 selenium 이 있는지 확인
#  pip install selenium 설치
#
# ```

# %%
import requests
import os
from bs4 import BeautifulSoup
import pandas as pd 
import numpy as np
from selenium import webdriver
import time

# %%
ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 2819-FF50
#
#  C:\workspace211115 디렉터리
#
# 2021-11-19  오전 10:45    <DIR>          .
# 2021-11-19  오전 10:45    <DIR>          ..
# 2021-11-15  오전 08:12    <DIR>          .idea
# 2021-11-19  오전 10:42    <DIR>          .ipynb_checkpoints
# 2021-11-14  오후 10:14    <DIR>          __메디치가산_빅데이타
# 2021-11-10  오후 05:25        11,372,032 chromedriver.exe
# 2021-11-19  오전 10:42         6,077,623 chromedriver_win32 (1).zip
# 2021-11-18  오전 10:27           347,286 coffee.jpg
# 2021-11-15  오전 09:45    <DIR>          data
# 2021-11-15  오전 11:20             3,382 day1_1.py
# 2021-11-15  오후 01:31             1,714 day1_2.py
# 2021-11-15  오후 02:38             3,402 day1_3.py
# 2021-11-15  오후 05:02             1,568 day1_4.py
# 2021-11-16  오전 09:23             4,626 day1_4_ans.py
# 2021-11-15  오후 05:38             1,742 day1_5.py
# 2021-11-15  오후 05:51               919 day1_6.py
# 2021-11-16  오전 10:28             4,202 day2_1.ipynb
# ...

# %% [markdown]
# ### 구글 검색엔진에서 검색어 결과 저장하기

# %%
# 1) 셀레니움 드라이버 객체 생성 => 크롬웹브라우저가 자동 실행 

# 같은 폴더안에 chromedriver.exe 
driver = webdriver.Chrome('chromedriver.exe')

# %%
# 2) 지연시간 지정 후에 웹브라우저 주소로 이동 
time.sleep(3)

url = 'http://www.google.com'
driver.get(url)

# %%
# 3) 구글 검색창에 검색어를 입력하고 결과 페이지를 출력하기 

# name 속성으로 요소 탐색 
# find_element_by_name(name속성값)

# 동작은?
# send_keys(키워드) : 텍스트필드에 값을 입력하는 이벤트 
# click() => 선택자 요소 클릭 
# submit() => 전송이벤트 

time.sleep(2)

# q 라는 이름을 가진 요소를 찾아서 글자 입력 
driver.find_element_by_name('q').send_keys('파이썬')
# 정보 전송 
driver.find_element_by_name('q').submit()

# %% [markdown]
# ### 선택자로 찾기
#
# - find_elements_by_css_selector(선택자) => 리스트로 반환
# - find_element_by_css_selector(선택자) => 첫번째 선택자에 해당하는 것만 반환
# ```
# .text => 문자열 반환
# .get_attribute(속성) => 속성에 해당하는 값이 반환
# ```

# %%
# 검색된 요소 블록을 선택자로 지정 => 리스트 
target = 'div.tF2Cxc > div.yuRUbf'
temp_list = driver.find_elements_by_css_selector(target)
print(temp_list)
print(len(temp_list))
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="954119a5f1ad21bdfa12d781a6725e90", element="b3c19830-002c-4029-950a-46875b943507")>, <selenium.webdriver.remote.webelement.WebElement (session="954119a5f1ad21bdfa12d781a6725e90", element="fd0db7a3-d960-49d5-9377-c57b7c2b799e")>, <selenium.webdriver.remote.webelement.WebElement (session="954119a5f1ad21bdfa12d781a6725e90", element="4192985e-1c5f-4855-aef6-f33de0001f5a")>, <selenium.webdriver.remote.webelement.WebElement (session="954119a5f1ad21bdfa12d781a6725e90", element="adbc2219-8af1-40a4-901e-3729ef9896e2")>, <selenium.webdriver.remote.webelement.WebElement (session="954119a5f1ad21bdfa12d781a6725e90", element="276ceca7-7e37-496c-8e90-138624b6d24a")>, <selenium.webdriver.remote.webelement.WebElement (session="954119a5f1ad21bdfa12d781a6725e90", element="4e0899aa-5845-4c1f-a8b2-9974fbc26d36")>, <selenium.webdriver.remote.webelement.WebElement (session="954119a5f1ad21bdfa12d781a6725e90", element="937b4eb0-75da-4225-9a41-fe0552
# ...

# %%
temp_list[0].text, temp_list[0].get_attribute('href')
# Out:
# ('Welcome to Python.org\nhttps://www.python.org', None)

# %%
<div class="tF2Cxc"><div class="yuRUbf">
<a href="https://www.python.org/" data-ved="2ahUKEwist-TdtKP0AhXVZt4KHbv_AFIQFnoECAYQAQ" ping="/url?sa=t&amp;source=web&amp;rct=j&amp;url=https://www.python.org/&amp;ved=2ahUKEwist-TdtKP0AhXVZt4KHbv_AFIQFnoECAYQAQ">
<br>
<h3 class="LC20lb MBeuO DKV0Md">Welcome to Python.org</h3>
<div class="TbwUpd NJjxre"><cite class="iUh30 tjvcx" role="text">https://www.python.org</cite></div>
</a>
<div class="B6fmyf"><div class="TbwUpd"><cite class="iUh30 tjvcx" role="text">https://www.python.org</cite></div><div class="eFM0qc"><span><div jscontroller="yGWMub" class="action-menu"><a href="#" class="GHDvEf" aria-label="검색결과 옵션" aria-expanded="false" aria-haspopup="true" role="button" jsaction="PZcoEd;keydown:wU6FVd;keypress:uWmNaf" data-ved="2ahUKEwist-TdtKP0AhXVZt4KHbv_AFIQ7B16BAgGEAI"><span class="gTl8xb"></span></a><ol class="action-menu-panel wHYlTd zsYMMe" role="menu" tabindex="-1" jsaction="keydown:Xiq7wd;mouseover:pKPowd;mouseout:O9bKS" data-ved="2ahUKEwist-TdtKP0AhXVZt4KHbv_AFIQqR96BAgGEAM"><li class="action-menu-item OhScic zsYMMe" role="menuitem"><a class="fl" href="https://webcache.googleusercontent.com/search?q=cache:Fvb7Gz_c4rwJ:https://www.python.org/+&amp;cd=1&amp;hl=ko&amp;ct=clnk&amp;gl=kr" ping="/url?sa=t&amp;source=web&amp;rct=j&amp;url=https://webcache.googleusercontent.com/search%3Fq%3Dcache:Fvb7Gz_c4rwJ:https://www.python.org/%2B%26cd%3D1%26hl%3Dko%26ct%3Dclnk%26gl%3Dkr&amp;ved=2ahUKEwist-TdtKP0AhXVZt4KHbv_AFIQIHoECAYQBA"><span>저장된&nbsp;페이지</span></a></li><li class="action-menu-item OhScic zsYMMe" role="menuitem"><a class="fl" href="/search?q=related:https://www.python.org/+%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;sa=X&amp;ved=2ahUKEwist-TdtKP0AhXVZt4KHbv_AFIQH3oECAYQBQ"><span>유사한 페이지</span></a></li></ol></div></span></div></div></div><div class="IsZvec"><div class="VwiC3b yXK7lf MUxGbd yDYNvb lyLwlc lEBKkf" style="-webkit-line-clamp:2"><span>The official home of the <em>Python</em> Programming Language.</span></div><div class="jYOxx"><div class="HiHjCd">‎<a href="https://www.python.org/downloads/" ping="/url?sa=t&amp;source=web&amp;rct=j&amp;url=https://www.python.org/downloads/&amp;ved=2ahUKEwist-TdtKP0AhXVZt4KHbv_AFIQ0gIoAHoECAUQAQ">Downloads</a> · ‎<a href="https://www.python.org/downloads/windows/" ping="/url?sa=t&amp;source=web&amp;rct=j&amp;url=https://www.python.org/downloads/windows/&amp;ved=2ahUKEwist-TdtKP0AhXVZt4KHbv_AFIQ0gIoAXoECAUQAg">Python Releases for Windows</a> · ‎<a href="https://www.python.org/downloads/release/python-3100/" ping="/url?sa=t&amp;source=web&amp;rct=j&amp;url=https://www.python.org/downloads/release/python-3100/&amp;ved=2ahUKEwist-TdtKP0AhXVZt4KHbv_AFIQ0gIoAnoECAUQAw">Python 3.10.0</a> · ‎<a href="https://www.python.org/about/gettingstarted/" ping="/url?sa=t&amp;source=web&amp;rct=j&amp;url=https://www.python.org/about/gettingstarted/&amp;ved=2ahUKEwist-TdtKP0AhXVZt4KHbv_AFIQ0gIoA3oECAUQBA">Python For Beginners</a></div></div></div><div jscontroller="K6HGfd" id="eob_16" jsdata="fxg5tf;_;CH0aqE" jsaction="rcuQ6b:npT2md" data-ved="2ahUKEwist-TdtKP0AhXVZt4KHbv_AFIQ2Z0BegQICRAC"><div jsname="UTgHCf" class="AUiS2" data-ved="2ahUKEwist-TdtKP0AhXVZt4KHbv_AFIQx40DegQIUBAA"><div jsname="d3PE6e" style="display:none"><div data-ved="2ahUKEwist-TdtKP0AhXVZt4KHbv_AFIQsKwBKAB6BAhQEAE">파이썬 // 연산자</div><div data-ved="2ahUKEwist-TdtKP0AhXVZt4KHbv_AFIQsKwBKAF6BAhQEAI">파이썬 설치</div><div data-ved="2ahUKEwist-TdtKP0AhXVZt4KHbv_AFIQsKwBKAJ6BAhQEAM">파이썬 다운</div><div data-ved="2ahUKEwist-TdtKP0AhXVZt4KHbv_AFIQsKwBKAN6BAhQEAQ">파이썬 코딩</div><div data-ved="2ahUKEwist-TdtKP0AhXVZt4KHbv_AFIQsKwBKAR6BAhQEAU">파이썬 코드</div><div data-ved="2ahUKEwist-TdtKP0AhXVZt4KHbv_AFIQsKwBKAV6BAhQEAY">파이썬 명령어</div></div><div><div jsname="l1CLDf" class="d8lLoc"><h4 jsname="IaVMje" class="eJ7tvc">함께 검색한 항목</h4><span jsname="ZnuYW" class="XCKyNd" jsaction="ornU0b" aria-label="추천 후속 작업을 닫습니다." role="button" tabindex="0"></span><div jsname="CeevUc" class="hYkSRb" style="display:none"></div></div></div></div></div></div>

# %%
# 첫번째 요소에 대한 텍스와 하이퍼링크 속성값 확인 
print(temp_list[0].find_element_by_css_selector('h3').text)
print(temp_list[0].find_element_by_css_selector('a').get_attribute('href'))
# Out:
# Welcome to Python.org
# https://www.python.org/

# %%
# 2차원 리스트 생성
temp_list2 = []
for row in temp_list:
    # 다시 a 요소의 href 속성값을 찾아서 저장 
    # find_element_by_css_selector(태그).get_attribute(속성)
    title = row.find_element_by_css_selector('h3').text    
    link = row.find_element_by_css_selector('a').get_attribute('href')
    temp_list2.append([title, link])
    
# 데이타프레임으로 저장 
df = pd.DataFrame(temp_list2, columns=['title', 'link'])
df
# Out:
#                                      title  \
# 0                    Welcome to Python.org
# 1                  파이썬 - 위키백과, 우리 모두의 백과사전
# 2                         Python - 나무위키:대문
# 3       1 파이썬 시작하기 - 왕초보를 위한 Python - 위키독스
# 4  누구나 코딩, 파이썬 시작하기(기초편) - 경기도 평생학습 포털 ...
# 5         파이썬(Python) - 코딩의 시작, TCP School
# 6   Python(파이썬) | 프로그래밍 언어 | 컴퓨터/IT - 교보문고
# 7                   혼자 공부하는 파이썬 - 한빛출판네트워크
#
#                                                 link
# 0                            https://www.python.org/
# 1  https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%...
# 2                         https://namu.wiki/w/Python
# 3                            https://wikidocs.net/43
# 4  https://www.gseek.kr/member/rl/courseInfo/onCo...
# 5                  http://tcpschool.com/python/intro
# 6  http://www.kyobobook.co.kr/category/categoryKo...
# 7  https://www.hanbit.co.kr/store/books/look.php?...

# %%
temp_list2
# Out:
# [['Welcome to Python.org', 'https://www.python.org/'],
#  ['파이썬 - 위키백과, 우리 모두의 백과사전',
#   'https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC'],
#  ['Python - 나무위키:대문', 'https://namu.wiki/w/Python'],
#  ['1 파이썬 시작하기 - 왕초보를 위한 Python - 위키독스', 'https://wikidocs.net/43'],
#  ['누구나 코딩, 파이썬 시작하기(기초편) - 경기도 평생학습 포털 ...',
#   'https://www.gseek.kr/member/rl/courseInfo/onCourseCsInfo.do?menuId=&menuStep=&pMenuId=OTOP&courseSeq=2440&courseCsSeq=1&courseCateCode=B300&eduTypeCode=&stuSeq='],
#  ['SUB) Why You Should Learn Python | Free Live Lecture',
#   'https://www.youtube.com/watch?v=8vjgx7joCqg'],
#  ['파이썬(Python) - 코딩의 시작, TCP School', 'http://tcpschool.com/python/intro'],
#  ['Python(파이썬) | 프로그래밍 언어 | 컴퓨터/IT - 교보문고',
#   'http://www.kyobobook.co.kr/category/categoryKor.laf?linkClass=331503&mallGb=KOR']]

# %%
# 지연시간 후에 웹브라우저 닫기 
time.sleep(3)
driver.close()

# %% [markdown]
# ### 검색된 전체 페이지 저장하기

# %%
# searchword = input('검색할 단어 입력 => ').strip()
searchword = '메디치 교육센터'

# 1)
# 크롬 웹브라우저 실행 => 구글 사이트로 이동 
# 검색어 입력 => 검색어 결과 페이지 표시 

driver = webdriver.Chrome('chromedriver.exe')
time.sleep(6)

url = 'http://www.google.com'
driver.get(url)

time.sleep(10)

# (2) 검색키워드를 입력받아서 전달 

driver.find_element_by_name('q').send_keys(searchword)
driver.find_element_by_name('q').submit()

# 3) 검색 결과 저장 
search_list = []
target = 'div.tF2Cxc > div.yuRUbf'

# 페이지 번호 
page = 0 

while True:
    # 현재 페이지 출력 
    print(f'Page = {page+1}')
    
    # 추출 블록 요소 리스트 저장 => 셀레니움객체 요소
    temp_list = driver.find_elements_by_css_selector(target)
    
    for row in temp_list:
        title = row.find_element_by_css_selector('h3').text
        url = row.find_element_by_css_selector('a').get_attribute('href')
        search_list.append([title, url])
    
    # 다음버튼 의 css 선택자 => #pnnext
    if driver.find_elements_by_css_selector('#pnnext'):
        # 다음 버튼 요소 선택 후 클릭 => 다음 페이지로 이동 
        driver.find_element_by_css_selector('#pnnext').click()
        time.sleep(6)
        page += 1
    # 탈출 조건 
    else:
        break

        
# 데이타프레임으로 저장 
df = pd.DataFrame(search_list, columns=['title', 'link'])
df  

# 마지막 => 지연시간 후에 웹브라우저 닫기 
time.sleep(6)
driver.close()
# Out:
# Page = 1

# %%
# 1)
# 크롬 웹브라우저 실행 => 구글 사이트로 이동 
# 검색어 입력 => 검색어 결과 페이지 표시 

driver = webdriver.Chrome('chromedriver.exe')
time.sleep(3)

url = 'http://www.google.com'
driver.get(url)

time.sleep(3)

# 검색키워드를 입력받아서 전달 
searchword = input('검색할 단어 입력 => ').strip()
driver.find_element_by_name('q').send_keys(searchword)
driver.find_element_by_name('q').submit()


# 2) 검색 결과 저장 
search_list = []
target = 'div.tF2Cxc > div.yuRUbf'

page = 0 

while True:
    print(f'Page = {page+1}')
    temp_list = driver.find_elements_by_css_selector(target)
    
    for item in temp_list:
        title = item.find_element_by_css_selector('h3').text
        url = item.find_element_by_css_selector('a').get_attribute('href')
        search_list.append([title, url])
    
    if driver.find_elements_by_css_selector('#pnnext'):
        # 다음 버튼 요소 선택 후 클릭 
        driver.find_element_by_css_selector('#pnnext').click()
        time.sleep(3)
        page += 1
    
    else:
        break
    
    
print(len(search_list))
# Out:
# 검색할 단어 입력 => 메디치 교육센터
# Page = 1
# Page = 2
# Page = 3
# Page = 4
# Page = 5
# Page = 6
# 52

# %%
# 데이타프레임으로 저장 
df = pd.DataFrame(search_list, columns=['title', 'link'])
df  

# 지연시간 후에 웹브라우저 닫기 
time.sleep(3)
driver.close()
# Out:
#                                                 title  \
# 0                                             메디치교육센터
# 1                                     모집 과정 - 메디치교육센터
# 2                                             메디치이모저모
# 3                                   질문답변게시판 - 메디치교육센터
# 4                                    함께하는 분 - 메디치교육센터
# 5                                     처음페이지 - 메디치교육센터
# 6              VR/AR/MR 융합콘텐츠 개발 실무 프로젝트 과정 - 메디치교육센터
# 7                                   메디치교육센터(가산디지털단지역)
# 8                                      메디치교육센터 - Home
# 9                                      메디치교육센터 평생교육시설
# 10               메디치교육센터 - [취업 연계형 무료교육] VR/AR - 로켓펀치
# 11                           [메디치이앤에스] 메디치교육센터 - 이벤터스
# 12                                메디치교육센터 - Instagram
# 13           컴퓨터학과 [메디치교육센터] 2020 혁신성장사업 AR/VR/MR ...
# 14          메디치이앤에스(주) 2021년 기업정보 | 사원수 34명, 근무환경 ...
# 15                                            교육기관 소개
# ...
