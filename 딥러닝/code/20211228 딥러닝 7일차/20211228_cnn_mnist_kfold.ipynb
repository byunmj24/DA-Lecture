# %% [markdown]
# # 이전 DNN 코드

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Input, Reshape

from sklearn.model_selection import KFold

import time

# %%
(raw_train_x, raw_train_y), (raw_test_x, raw_test_y) = tf.keras.datasets.mnist.load_data()

raw_x = np.concatenate((raw_train_x, raw_test_x), axis=0)
raw_y = np.concatenate((raw_train_y, raw_test_y), axis=0)

x = raw_x/255.
y = raw_y/255.

# %% [markdown]
# ## 모델 생성 함수 정

# %%
def build_model():  
  model = keras.Sequential()
  model.add(Input((28,28)))
  model.add(Reshape((28,28,1))) # ADDED
  model.add(Conv2D(32, (3, 3), padding='same')) # ADDED
  model.add(MaxPooling2D((2, 2))) # ADDED
  model.add(Conv2D(64, (3, 3), padding='same')) # ADDED
  model.add(MaxPooling2D((2, 2))) # ADDED
  model.add(Flatten())
  model.add(Dense(10, activation='relu'))
  model.add(Dense(10, activation='relu'))
  model.add(Dense(10, activation='softmax'))

  model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

  return model

# %%
fold_count = 5

# %%
from sklearn.model_selection import KFold

kfold = KFold(n_splits=fold_count, shuffle=True)

losses = []
acces = []

for train, test in kfold.split(x, y):

  model = build_model()

  history = model.fit(x[train], y[train], batch_size=32, epochs=2, validation_split=0.2)

  loss, acc = model.evaluate(x[test], y[test])
  print("loss =", loss)
  print("acc =", acc)
  losses.append(loss)
  acces.append(acc)
# Out:
# Epoch 1/2
# 1400/1400 [==============================] - 14s 4ms/step - loss: 0.0106 - accuracy: 0.0990 - val_loss: 6.5741e-07 - val_accuracy: 0.0990
# Epoch 2/2
# 1400/1400 [==============================] - 5s 3ms/step - loss: 5.1020e-07 - accuracy: 0.0991 - val_loss: 3.8129e-07 - val_accuracy: 0.0990
# 438/438 [==============================] - 2s 4ms/step - loss: 3.9163e-07 - accuracy: 0.0969
# loss = 3.916300954642793e-07
# acc = 0.09685714542865753
# Epoch 1/2
# 1400/1400 [==============================] - 5s 4ms/step - loss: 0.0165 - accuracy: 0.0978 - val_loss: 2.5502e-06 - val_accuracy: 0.0972
# Epoch 2/2
# 1400/1400 [==============================] - 5s 4ms/step - loss: 1.5433e-06 - accuracy: 0.0982 - val_loss: 8.8557e-07 - val_accuracy: 0.0972
# 438/438 [==============================] - 1s 3ms/step - loss: 8.7355e-07 - accuracy: 0.1010
# loss = 8.735513574720244e-07
# acc = 0.10100000351667404
# Epoch 1/2
# 1400/1400 [==============================] - 5s 4ms/step - loss: 0.0119 - accuracy: 0.0987 - val_loss: 2.5224e-06 - val_accuracy: 0.0984
# Epoch 2/2
# 1400/1400 [==============================] - 5s 3ms/step - loss: 1.4524e-06 - accuracy: 0.0988 - val_loss: 7.3356e-07 - val_accuracy: 0.0984
# 438/438 [==============================] - 1s 3ms/step - loss: 8.1272e-07 - accuracy: 0.0982
# loss = 8.127241812871944e-07
# acc = 0.0982142835855484
# Epoch 1/2
# 1400/1400 [==============================] - 5s 4ms/step - loss: 0.0165 - accuracy: 0.0974 - val_loss: 2.9234e-06 - val_accuracy: 0.0983
# Epoch 2/2
# 1400/1400 [==============================] - 5s 3ms/step - loss: 1.5753e-06 - accuracy: 0.0982 - val_loss: 7.8684e-07 - val_accuracy: 0.0983
# 438/438 [==============================] - 1s 3ms/step - loss: 7.8700e-07 - accuracy: 0.1003
# loss = 7.869996352383168e-07
# acc = 0.10028571635484695
# Epoch 1/2
# 1400/1400 [==============================] - 5s 4ms/step - loss: 0.0221 - accuracy: 0.0986 - val_loss: 3.2895e-06 - val_accuracy: 0.0975
# Epoch 2/2
# 1400/1400 [==============================] - 5s 3ms/step - loss: 2.0711e-06 - accuracy: 0.0995 - val_loss: 1.2429e-06 - val_accuracy: 0.0975
# 438/438 [==============================] - 1s 3ms/step - loss: 1.1721e-06 - accuracy: 0.0967
# loss = 1.1720730981323868e-06
# acc = 0.09671428799629211

# %%
average_acc = sum(acces) / fold_count
print("average acc=", average_acc)
# Out:
# average acc= 0.0986142873764038

# %%
model = keras.Sequential()
model.add(Input((28,28)))
model.add(Flatten())
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
model.summary()


model.fit(train_x, train_y, epochs=5, verbose=1, batch_size=128)


loss, acc = model.evaluate(test_x, test_y)
print("loss=",loss)
print("acc=",acc)

y_ = model.predict(test_x)
predicted = np.argmax(y_, axis=1)

print(predicted)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0821 00:48:13.984249 140281580390272 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                7850
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                110
# =================================================================
# Total params: 8,070
# Trainable params: 8,070
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.7731 - acc: 0.7749
# Epoch 2/5
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.3412 - acc: 0.9015
# Epoch 3/5
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.2946 - acc: 0.9146
# Epoch 4/5
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.2712 - acc: 0.9217
# Epoch 5/5
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.2559 - acc: 0.9261
# 10000/10000 [==============================] - 0s 28us/sample - loss: 0.2579 - acc: 0.9250
# loss= 0.25794000726342203
# acc= 0.925
# [7 2 1 ... 4 5 6]

# %% [markdown]
# # CNN

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Input, Reshape

import time

# %%
(raw_train_x, raw_train_y), (raw_test_x, raw_test_y) = tf.keras.datasets.mnist.load_data()

train_x = raw_train_x/255.
test_x = raw_test_x/255.

train_y = raw_train_y
test_y = raw_test_y

# %%
model = keras.Sequential()
model.add(Input((28,28)))
model.add(Reshape((28,28,1))) # ADDED
model.add(Conv2D(32, (3, 3), padding='same')) # ADDED
model.add(MaxPooling2D((2, 2))) # ADDED
model.add(Conv2D(64, (3, 3), padding='same')) # ADDED
model.add(MaxPooling2D((2, 2))) # ADDED
model.add(Flatten())
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='softmax'))


model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
model.summary()


model.fit(train_x, train_y, epochs=5, verbose=1, batch_size=128)


loss, acc = model.evaluate(test_x, test_y)
print("loss=",loss)
print("acc=",acc)

y_ = model.predict(test_x)
predicted = np.argmax(y_, axis=1)

print(predicted)
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                16010
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                110
# =================================================================
# Total params: 35,046
# Trainable params: 35,046
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 469/469 [==============================] - 51s 106ms/step - loss: 0.6707 - accuracy: 0.7919
# Epoch 2/5
# 469/469 [==============================] - 45s 96ms/step - loss: 0.2102 - accuracy: 0.9399
# Epoch 3/5
# 469/469 [==============================] - 45s 95ms/step - loss: 0.1335 - accuracy: 0.9615
# Epoch 4/5
# 469/469 [==============================] - 47s 99ms/step - loss: 0.1014 - accuracy: 0.9695
# Epoch 5/5
# 469/469 [==============================] - 46s 98ms/step - loss: 0.0869 - accuracy: 0.9738
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0794 - accuracy: 0.9766
# loss= 0.07944491505622864
# acc= 0.9765999913215637
# [7 2 1 ... 4 5 6]

# %% [markdown]
# conv2d 레이어의 파라매터 수는 다음에 의해서 결정된다.
# ```
# 파라매터 수 = (conv필터 가로 * conv 필터 세로 * 데이터 깊이 + bias 1개) * 필터 수
# ```
# 위 모델의 경우 파라매터 수 320, 18496은 다음과 같이 결정된다.
#
# ```
# 320 = (3*3*1+1) * 32
#
# 18496 = (3*3*32+1)*64
# ```
#
# ```
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# ```

# %% [markdown]
# # 영상 데이터 분류 CNN Template

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Input, Reshape

import time

(raw_train_x, raw_train_y), (raw_test_x, raw_test_y) = tf.keras.datasets.mnist.load_data()

train_x = raw_train_x/255.
test_x = raw_test_x/255.

train_y = raw_train_y
test_y = raw_test_y

model = keras.Sequential()
model.add(Input((28,28)))
model.add(Reshape((28,28,1)))
model.add(Conv2D(32, (3, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='softmax'))


model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
model.summary()


model.fit(train_x, train_y, epochs=5, verbose=1, batch_size=128)


loss, acc = model.evaluate(test_x, test_y)
print("loss=",loss)
print("acc=",acc)

y_ = model.predict(test_x)
predicted = np.argmax(y_, axis=1)

print(predicted)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                16010
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                110
# =================================================================
# Total params: 35,046
# Trainable params: 35,046
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 469/469 [==============================] - 56s 118ms/step - loss: 0.5551 - accuracy: 0.8262
# Epoch 2/5
# 469/469 [==============================] - 42s 89ms/step - loss: 0.1448 - accuracy: 0.9573
# Epoch 3/5
# 469/469 [==============================] - 43s 91ms/step - loss: 0.0972 - accuracy: 0.9714
# Epoch 4/5
# 469/469 [==============================] - 43s 92ms/step - loss: 0.0756 - accuracy: 0.9779
# Epoch 5/5
# 469/469 [==============================] - 42s 89ms/step - loss: 0.0649 - accuracy: 0.9804
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0672 - accuracy: 0.9785
# loss= 0.06722691655158997
# acc= 0.9785000085830688
# [7 2 1 ... 4 5 6]
