# %%
a = [-4, -3, -2, -1, 0, 1, 2, 3, 4]

# list b : a*2 + 1
b = [ i*2 + 1 for i in a ]
print(b)

# %%
# list b : abs(a)
b = [ abs(i) for i in a ]
print(b)

# %%
def my_func(v):
    return v*3

# %%
# list b : my_func(a)
b = [ my_func(i) for i in a ]
print(b)
